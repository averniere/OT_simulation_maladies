# %%
#from data import load_data
import numpy as np
import json
import os
import matplotlib.pyplot as plt
import torch

from HGCN import OT
from HGCN import poincare
from HGCN import data 
from HGCN import evaluation
from HGCN.load_data import *
# Out:
# /home/onyxia/work/OT_simulation_maladies/HGCN/OT.py:593: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_ylabel('$||P^* - P_\epsilon^*||_F$', fontsize=25)
# /home/onyxia/work/OT_simulation_maladies/HGCN/OT.py:599: SyntaxWarning: invalid escape sequence '\e'
#   ax[1].set_xlabel('Regularization Strength $\epsilon$', fontsize=25)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       4 import os
#       5 import matplotlib.pyplot as plt
#       6 import torch
#       7
# ----> 8 from HGCN import OT
#       9 from HGCN import poincare
#      10 from HGCN import data
#      11 from HGCN import evaluation
#
# File ~/work/OT_simulation_maladies/HGCN/OT.py:8
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
# ----> 8 import frechetmean as fm
#      10 from joblib import Parallel, delayed
#      11 from tqdm import tqdm
#
# ...
